# %% [markdown]
# # Python Programming basics

# %% [markdown]
# ## Types and Functions

# %% [markdown]
# Extend the function to take an optional 3rd argument.
#
# ---

# %% [markdown]
# Extend the function to take another optional flag parameter and add only if it is true

# %%
# def add(x, y):
#     return

# def add(x, y, z):

# def add(x, y, z, flag=None):

def add(x, y, z, flag=False):
  if flag:
    return x+y+z



print(add(1,2,3))
# Out:
# None

# %% [markdown]
# Assign a function to a variable 'a' and print the output

# %%
a = add
print(a(1,2,3, 1))
# Out:
# 6

# %% [markdown]
# ## Iterations in python

# %% [markdown]
# Create a list of 5 elements

# %%
mylist = [1, 2, 3, 4, 5]

# %% [markdown]
# Square every item in the list using a loop inside the array index

# %%
for i in range(len(mylist)):
  mylist[i] = mylist[i]**2

mylist
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Show how to use a iterator. First, use enumerate to create a new tuple from above list

# %%
#use of a iterator
#iterator- returns numbers that starts with 25 and each and every time it is passed it gets squared.

class MyInit:
  def __init__(self):
      self.a = 25

  def __iter__(self):
      return self

  def __next__(self):
      value = self.a
      self.a = self.a**2
      return value

obj = MyInit()
itr = iter(obj)

print(next(itr))
print(next(itr))
print(next(itr))
# Out:
# 25
# 625
# 390625

# %%
tup = tuple(enumerate(mylist))
print(tup)
# Out:
# ((0, 1), (1, 4), (2, 9), (3, 16), (4, 25))

# %% [markdown]
# Now use a zip iterator to do the same.

# %%
rng = range(len(mylist))
answer = tuple(zip(rng, mylist))
print(answer)
# Out:
# ((0, 1), (1, 4), (2, 9), (3, 16), (4, 25))

# %% [markdown]
# Now state the differences between a zip and enumerate iterator.

# %% [markdown]
# Python`enumerate()` and `zip()` are built-in functions that can be used on sequences.
#
# `enumerate()` function can be use to iterate over indices and items of a list.
#
# `zip()` function make an iterator that aggregates elements from each of the iterables. In simple words it can be used to iterate over two or more lists in parallel.

# %% [markdown]
# ## Strings in Python

# %% [markdown]
# Open the file poem.txt and print lenght of each line.

# %% [markdown]
# Find sum of each line, mean, median and standard deviation of all lines in the file.

# %% [markdown]
# Count the number of words in the file

# %% [markdown]
# Print the first 1000 characters from poem.txt.

# %% [markdown]
# Print the 3rd to 5th words from the file.

# %%
with open('poem.txt','r') as file:
  lines = file.readlines()

  line_lengths = []

  tup = enumerate(lines, start=1)

  for i, x in tup:
    print(f"length of line {i} = {len(x)}")
# Out:
# length of line 1 = 6
# length of line 2 = 26
# length of line 3 = 1
# length of line 4 = 23
# length of line 5 = 1
# length of line 6 = 1
# length of line 7 = 1
# length of line 8 = 1
# length of line 9 = 21
# length of line 10 = 1
# length of line 11 = 27
# length of line 12 = 59
# length of line 13 = 28
# length of line 14 = 27
# length of line 15 = 26
# length of line 16 = 21
# length of line 17 = 21
# length of line 18 = 23
# length of line 19 = 24
# length of line 20 = 17
# length of line 21 = 23
# length of line 22 = 10
# length of line 23 = 20
# length of line 24 = 19
# length of line 25 = 21
# length of line 26 = 31
# length of line 27 = 9
# length of line 28 = 27
# length of line 29 = 30
# length of line 30 = 11
# length of line 31 = 21
# length of line 32 = 26
# length of line 33 = 1
# length of line 34 = 50
# length of line 35 = 31
# length of line 36 = 1
# length of line 37 = 66
# length of line 38 = 12
# length of line 39 = 1
# length of line 40 = 17
# length of line 41 = 1
# length of line 42 = 1
# length of line 43 = 1
# length of line 44 = 7
# length of line 45 = 1
# length of line 46 = 49
# length of line 47 = 1
# length of line 48 = 48
# length of line 49 = 1
# length of line 50 = 5
# length of line 51 = 13
# length of line 52 = 1
# length of line 53 = 6
# length of line 54 = 44
# length of line 55 = 1
# length of line 56 = 5
# length of line 57 = 20
# length of line 58 = 1
# length of line 59 = 6
# length of line 60 = 10
# length of line 61 = 1
# length of line 62 = 5
# length of line 63 = 4
# length of line 64 = 1
# length of line 65 = 6
# length of line 66 = 40
# length of line 67 = 1
# length of line 68 = 5
# length of line 69 = 52
# length of line 70 = 1
# length of line 71 = 6
# length of line 72 = 47
# length of line 73 = 24
# length of line 74 = 1
# length of line 75 = 5
# length of line 76 = 26
# length of line 77 = 1
# length of line 78 = 6
# length of line 79 = 22
# length of line 80 = 1
# length of line 81 = 5
# length of line 82 = 18
# length of line 83 = 38
# length of line 84 = 45
# length of line 85 = 1
# length of line 86 = 6
# length of line 87 = 47
# length of line 88 = 1
# length of line 89 = 31
# length of line 90 = 1
# length of line 91 = 5
# length of line 92 = 24
# length of line 93 = 1
# length of line 94 = 5
# length of line 95 = 26
# length of line 96 = 1
# length of line 97 = 6
# length of line 98 = 21
# length of line 99 = 1
# length of line 100 = 5
# length of line 101 = 29
# length of line 102 = 23
# length of line 103 = 1
# length of line 104 = 6
# length of line 105 = 23
# length of line 106 = 21
# length of line 107 = 1
# length of line 108 = 8
# length of line 109 = 1
# length of line 110 = 5
# length of line 111 = 17
# length of line 112 = 1
# length of line 113 = 5
# length of line 114 = 5
# length of line 115 = 24
# length of line 116 = 1
# length of line 117 = 5
# length of line 118 = 16
# length of line 119 = 1
# length of line 120 = 5
# length of line 121 = 44
# length of line 122 = 1
# length of line 123 = 5
# length of line 124 = 46
# length of line 125 = 1
# length of line 126 = 5
# length of line 127 = 21
# length of line 128 = 1
# length of line 129 = 5
# length of line 130 = 35
# length of line 131 = 41
# length of line 132 = 47
# length of line 133 = 37
# length of line 134 = 44
# length of line 135 = 36
# length of line 136 = 41
# length of line 137 = 1
# length of line 138 = 5
# length of line 139 = 31
# length of line 140 = 1
# length of line 141 = 5
# length of line 142 = 17
# length of line 143 = 40
# length of line 144 = 41
# length of line 145 = 30
# length of line 146 = 1
# length of line 147 = 5
# length of line 148 = 19
# length of line 149 = 40
# length of line 150 = 1
# length of line 151 = 5
# length of line 152 = 19
# length of line 153 = 50
# length of line 154 = 50
# length of line 155 = 42
# length of line 156 = 29
# length of line 157 = 1
# length of line 158 = 5
# length of line 159 = 50
# length of line 160 = 1
# length of line 161 = 22
# length of line 162 = 1
# length of line 163 = 5
# length of line 164 = 47
# length of line 165 = 1
# length of line 166 = 5
# length of line 167 = 42
# length of line 168 = 1
# length of line 169 = 5
# length of line 170 = 46
# length of line 171 = 1
# length of line 172 = 5
# length of line 173 = 48
# length of line 174 = 1
# length of line 175 = 5
# length of line 176 = 22
# length of line 177 = 1
# length of line 178 = 5
# length of line 179 = 22
# length of line 180 = 1
# length of line 181 = 5
# length of line 182 = 49
# length of line 183 = 41
# length of line 184 = 39
# length of line 185 = 53
# length of line 186 = 1
# length of line 187 = 5
# length of line 188 = 16
# length of line 189 = 1
# length of line 190 = 5
# length of line 191 = 21
# length of line 192 = 1
# length of line 193 = 5
# length of line 194 = 41
# length of line 195 = 1
# length of line 196 = 14
# length of line 197 = 1
# length of line 198 = 5
# length of line 199 = 32
# length of line 200 = 1
# length of line 201 = 5
# length of line 202 = 45
# length of line 203 = 41
# length of line 204 = 21
# length of line 205 = 1
# length of line 206 = 5
# length of line 207 = 40
# length of line 208 = 37
# length of line 209 = 18
# length of line 210 = 1
# length of line 211 = 5
# length of line 212 = 25
# length of line 213 = 1
# length of line 214 = 5
# length of line 215 = 24
# length of line 216 = 35
# length of line 217 = 39
# length of line 218 = 44
# length of line 219 = 41
# length of line 220 = 14
# length of line 221 = 1
# length of line 222 = 5
# length of line 223 = 47
# length of line 224 = 46
# length of line 225 = 1
# length of line 226 = 5
# length of line 227 = 47
# length of line 228 = 43
# length of line 229 = 47
# length of line 230 = 1
# length of line 231 = 5
# length of line 232 = 48
# length of line 233 = 46
# length of line 234 = 42
# length of line 235 = 42
# length of line 236 = 40
# length of line 237 = 49
# length of line 238 = 42
# length of line 239 = 45
# length of line 240 = 49
# length of line 241 = 29
# length of line 242 = 1
# length of line 243 = 5
# length of line 244 = 12
# length of line 245 = 46
# length of line 246 = 41
# length of line 247 = 43
# length of line 248 = 44
# length of line 249 = 52
# length of line 250 = 52
# length of line 251 = 52
# length of line 252 = 35
# length of line 253 = 49
# length of line 254 = 44
# length of line 255 = 38
# length of line 256 = 42
# length of line 257 = 34
# length of line 258 = 49
# length of line 259 = 38
# length of line 260 = 48
# length of line 261 = 35
# length of line 262 = 46
# length of line 263 = 40
# length of line 264 = 38
# length of line 265 = 47
# length of line 266 = 41
# length of line 267 = 38
# length of line 268 = 45
# length of line 269 = 44
# length of line 270 = 40
# length of line 271 = 49
# length of line 272 = 43
# length of line 273 = 1
# length of line 274 = 5
# length of line 275 = 36
# length of line 276 = 46
# length of line 277 = 48
# length of line 278 = 44
# length of line 279 = 1
# length of line 280 = 5
# length of line 281 = 40
# length of line 282 = 42
# length of line 283 = 40
# length of line 284 = 50
# length of line 285 = 44
# length of line 286 = 49
# length of line 287 = 42
# length of line 288 = 46
# length of line 289 = 42
# length of line 290 = 47
# length of line 291 = 41
# length of line 292 = 38
# length of line 293 = 44
# length of line 294 = 37
# length of line 295 = 45
# length of line 296 = 1
# length of line 297 = 18
# length of line 298 = 1
# length of line 299 = 52
# length of line 300 = 41
# length of line 301 = 13
# length of line 302 = 39
# length of line 303 = 43
# length of line 304 = 13
# length of line 305 = 41
# length of line 306 = 39
# length of line 307 = 10
# length of line 308 = 38
# length of line 309 = 40
# length of line 310 = 52
# length of line 311 = 18
# length of line 312 = 52
# length of line 313 = 1
# length of line 314 = 5
# length of line 315 = 39
# length of line 316 = 1
# length of line 317 = 5
# length of line 318 = 26
# length of line 319 = 1
# length of line 320 = 5
# length of line 321 = 11
# length of line 322 = 1
# length of line 323 = 5
# length of line 324 = 11
# length of line 325 = 1
# length of line 326 = 5
# length of line 327 = 11
# length of line 328 = 1
# length of line 329 = 14
# length of line 330 = 1
# length of line 331 = 37
# length of line 332 = 34
# length of line 333 = 37
# length of line 334 = 38
# length of line 335 = 1
# length of line 336 = 5
# length of line 337 = 43
# length of line 338 = 1
# length of line 339 = 5
# length of line 340 = 41
# length of line 341 = 37
# length of line 342 = 43
# length of line 343 = 47
# length of line 344 = 42
# length of line 345 = 41
# length of line 346 = 39
# length of line 347 = 40
# length of line 348 = 36
# length of line 349 = 1
# length of line 350 = 5
# length of line 351 = 37
# length of line 352 = 45
# length of line 353 = 43
# length of line 354 = 44
# length of line 355 = 48
# length of line 356 = 50
# length of line 357 = 47
# length of line 358 = 41
# length of line 359 = 1
# length of line 360 = 5
# length of line 361 = 44
# length of line 362 = 44
# length of line 363 = 46
# length of line 364 = 41
# length of line 365 = 41
# length of line 366 = 38
# length of line 367 = 44
# length of line 368 = 46
# length of line 369 = 43
# length of line 370 = 1
# length of line 371 = 5
# length of line 372 = 44
# length of line 373 = 43
# length of line 374 = 1
# length of line 375 = 10
# length of line 376 = 1
# length of line 377 = 1
# length of line 378 = 1
# length of line 379 = 51
# length of line 380 = 1
# length of line 381 = 62
# length of line 382 = 34
# length of line 383 = 1
# length of line 384 = 6
# length of line 385 = 46
# length of line 386 = 45
# length of line 387 = 51
# length of line 388 = 37
# length of line 389 = 46
# length of line 390 = 41
# length of line 391 = 40
# length of line 392 = 46
# length of line 393 = 46
# length of line 394 = 42
# length of line 395 = 41
# length of line 396 = 51
# length of line 397 = 44
# length of line 398 = 41
# length of line 399 = 44
# length of line 400 = 45
# length of line 401 = 46
# length of line 402 = 38
# length of line 403 = 45
# length of line 404 = 43
# length of line 405 = 45
# length of line 406 = 46
# length of line 407 = 39
# length of line 408 = 43
# length of line 409 = 48
# length of line 410 = 46
# length of line 411 = 46
# length of line 412 = 40
# length of line 413 = 42
# length of line 414 = 43
# length of line 415 = 45
# length of line 416 = 45
# length of line 417 = 42
# length of line 418 = 41
# length of line 419 = 44
# length of line 420 = 40
# length of line 421 = 47
# length of line 422 = 33
# length of line 423 = 48
# length of line 424 = 1
# length of line 425 = 15
# length of line 426 = 46
# length of line 427 = 1
# length of line 428 = 6
# length of line 429 = 40
# length of line 430 = 1
# length of line 431 = 34
# length of line 432 = 1
# length of line 433 = 44
# length of line 434 = 46
# length of line 435 = 40
# length of line 436 = 53
# length of line 437 = 44
# length of line 438 = 42
# length of line 439 = 41
# length of line 440 = 45
# length of line 441 = 33
# length of line 442 = 1
# length of line 443 = 6
# length of line 444 = 15
# length of line 445 = 43
# length of line 446 = 48
# length of line 447 = 36
# length of line 448 = 41
# length of line 449 = 49
# length of line 450 = 48
# length of line 451 = 1
# length of line 452 = 6
# length of line 453 = 50
# length of line 454 = 1
# length of line 455 = 5
# length of line 456 = 46
# length of line 457 = 36
# length of line 458 = 40
# length of line 459 = 40
# length of line 460 = 1
# length of line 461 = 6
# length of line 462 = 44
# length of line 463 = 44
# length of line 464 = 40
# length of line 465 = 1
# length of line 466 = 5
# length of line 467 = 53
# length of line 468 = 1
# length of line 469 = 6
# length of line 470 = 45
# length of line 471 = 1
# length of line 472 = 5
# length of line 473 = 43
# length of line 474 = 1
# length of line 475 = 7
# length of line 476 = 42
# length of line 477 = 49
# length of line 478 = 37
# length of line 479 = 39
# length of line 480 = 52
# length of line 481 = 36
# length of line 482 = 1
# length of line 483 = 5
# length of line 484 = 25
# length of line 485 = 1
# length of line 486 = 7
# length of line 487 = 10
# length of line 488 = 38
# length of line 489 = 1
# length of line 490 = 5
# length of line 491 = 44
# length of line 492 = 43
# length of line 493 = 37
# length of line 494 = 40
# length of line 495 = 39
# length of line 496 = 40
# length of line 497 = 48
# length of line 498 = 47
# length of line 499 = 44
# length of line 500 = 43
# length of line 501 = 46
# length of line 502 = 1
# length of line 503 = 6
# length of line 504 = 51
# length of line 505 = 46
# length of line 506 = 47
# length of line 507 = 52
# length of line 508 = 36
# length of line 509 = 42
# length of line 510 = 37
# length of line 511 = 45
# length of line 512 = 42
# length of line 513 = 39
# length of line 514 = 40
# length of line 515 = 43
# length of line 516 = 39
# length of line 517 = 42
# length of line 518 = 47
# length of line 519 = 45
# length of line 520 = 42
# length of line 521 = 47
# length of line 522 = 47
# length of line 523 = 47
# length of line 524 = 39
# length of line 525 = 44
# length of line 526 = 42
# length of line 527 = 34
# length of line 528 = 45
# length of line 529 = 40
# length of line 530 = 39
# length of line 531 = 37
# length of line 532 = 38
# length of line 533 = 42
# length of line 534 = 44
# length of line 535 = 1
# length of line 536 = 7
# length of line 537 = 45
# length of line 538 = 48
# length of line 539 = 1
# length of line 540 = 5
# length of line 541 = 40
# length of line 542 = 1
# length of line 543 = 6
# length of line 544 = 37
# length of line 545 = 40
# length of line 546 = 42
# length of line 547 = 44
# length of line 548 = 44
# length of line 549 = 47
# length of line 550 = 51
# length of line 551 = 40
# length of line 552 = 1
# length of line 553 = 25
# length of line 554 = 1
# length of line 555 = 5
# length of line 556 = 44
# length of line 557 = 37
# length of line 558 = 38
# length of line 559 = 48
# length of line 560 = 41
# length of line 561 = 39
# length of line 562 = 42
# length of line 563 = 52
# length of line 564 = 48
# length of line 565 = 49
# length of line 566 = 40
# length of line 567 = 45
# length of line 568 = 45
# length of line 569 = 46
# length of line 570 = 44
# length of line 571 = 37
# length of line 572 = 46
# length of line 573 = 54
# length of line 574 = 44
# length of line 575 = 46
# length of line 576 = 45
# length of line 577 = 47
# length of line 578 = 53
# length of line 579 = 48
# length of line 580 = 36
# length of line 581 = 43
# length of line 582 = 42
# length of line 583 = 45
# length of line 584 = 42
# length of line 585 = 39
# length of line 586 = 48
# length of line 587 = 1
# length of line 588 = 42
# length of line 589 = 1
# length of line 590 = 5
# length of line 591 = 23
# length of line 592 = 1
# length of line 593 = 5
# length of line 594 = 27
# length of line 595 = 33
# length of line 596 = 1
# length of line 597 = 5
# length of line 598 = 47
# length of line 599 = 1
# length of line 600 = 5
# length of line 601 = 53
# length of line 602 = 46
# length of line 603 = 11
# length of line 604 = 1
# length of line 605 = 5
# length of line 606 = 16
# length of line 607 = 1
# length of line 608 = 5
# length of line 609 = 46
# length of line 610 = 46
# length of line 611 = 1
# length of line 612 = 5
# length of line 613 = 36
# length of line 614 = 1
# length of line 615 = 5
# length of line 616 = 36
# length of line 617 = 39
# length of line 618 = 38
# length of line 619 = 44
# length of line 620 = 37
# length of line 621 = 46
# length of line 622 = 1
# length of line 623 = 5
# length of line 624 = 46
# length of line 625 = 1
# length of line 626 = 5
# length of line 627 = 42
# length of line 628 = 43
# length of line 629 = 1
# length of line 630 = 5
# length of line 631 = 40
# length of line 632 = 1
# length of line 633 = 5
# length of line 634 = 49
# length of line 635 = 46
# length of line 636 = 41
# length of line 637 = 40
# length of line 638 = 38
# length of line 639 = 1
# length of line 640 = 5
# length of line 641 = 16
# length of line 642 = 1
# length of line 643 = 5
# length of line 644 = 27
# length of line 645 = 1
# length of line 646 = 5
# length of line 647 = 38
# length of line 648 = 1
# length of line 649 = 5
# length of line 650 = 39
# length of line 651 = 38
# length of line 652 = 1
# length of line 653 = 5
# length of line 654 = 40
# length of line 655 = 1
# length of line 656 = 5
# length of line 657 = 9
# length of line 658 = 1
# length of line 659 = 5
# length of line 660 = 31
# length of line 661 = 1
# length of line 662 = 5
# length of line 663 = 20
# length of line 664 = 1
# length of line 665 = 5
# length of line 666 = 34
# length of line 667 = 40
# length of line 668 = 37
# length of line 669 = 20
# length of line 670 = 1
# length of line 671 = 5
# length of line 672 = 28
# length of line 673 = 1
# length of line 674 = 5
# length of line 675 = 41
# length of line 676 = 39
# length of line 677 = 42
# length of line 678 = 50
# length of line 679 = 34
# length of line 680 = 42
# length of line 681 = 48
# length of line 682 = 44
# length of line 683 = 54
# length of line 684 = 38
# length of line 685 = 45
# length of line 686 = 37
# length of line 687 = 48
# length of line 688 = 44
# length of line 689 = 49
# length of line 690 = 42
# length of line 691 = 31
# length of line 692 = 1
# length of line 693 = 5
# length of line 694 = 20
# length of line 695 = 1
# length of line 696 = 5
# length of line 697 = 45
# length of line 698 = 1
# length of line 699 = 5
# length of line 700 = 25
# length of line 701 = 1
# length of line 702 = 5
# length of line 703 = 16
# length of line 704 = 44
# length of line 705 = 38
# length of line 706 = 42
# length of line 707 = 42
# length of line 708 = 42
# length of line 709 = 29
# length of line 710 = 1
# length of line 711 = 5
# length of line 712 = 19
# length of line 713 = 1
# length of line 714 = 5
# length of line 715 = 43
# length of line 716 = 42
# length of line 717 = 23
# length of line 718 = 1
# length of line 719 = 5
# length of line 720 = 44
# length of line 721 = 29
# length of line 722 = 1
# length of line 723 = 14
# length of line 724 = 16
# length of line 725 = 1
# length of line 726 = 5
# length of line 727 = 16
# length of line 728 = 1
# length of line 729 = 6
# length of line 730 = 16
# length of line 731 = 1
# length of line 732 = 5
# length of line 733 = 17
# length of line 734 = 1
# length of line 735 = 6
# length of line 736 = 28
# length of line 737 = 1
# length of line 738 = 5
# length of line 739 = 27
# length of line 740 = 1
# length of line 741 = 5
# length of line 742 = 40
# length of line 743 = 1
# length of line 744 = 5
# length of line 745 = 28
# length of line 746 = 1
# length of line 747 = 5
# length of line 748 = 44
# length of line 749 = 1
# length of line 750 = 5
# length of line 751 = 13
# length of line 752 = 1
# length of line 753 = 5
# length of line 754 = 16
# length of line 755 = 1
# length of line 756 = 5
# length of line 757 = 29
# length of line 758 = 1
# length of line 759 = 5
# length of line 760 = 17
# length of line 761 = 1
# length of line 762 = 5
# length of line 763 = 26
# length of line 764 = 1
# length of line 765 = 5
# length of line 766 = 31
# length of line 767 = 1
# length of line 768 = 5
# length of line 769 = 38
# length of line 770 = 1
# length of line 771 = 5
# length of line 772 = 52
# length of line 773 = 1
# length of line 774 = 14
# length of line 775 = 16
# length of line 776 = 1
# length of line 777 = 5
# length of line 778 = 18
# length of line 779 = 1
# length of line 780 = 5
# length of line 781 = 29
# length of line 782 = 1
# length of line 783 = 5
# length of line 784 = 39
# length of line 785 = 18
# length of line 786 = 1
# length of line 787 = 5
# length of line 788 = 23
# length of line 789 = 29
# length of line 790 = 1
# length of line 791 = 5
# length of line 792 = 19
# length of line 793 = 1
# length of line 794 = 5
# length of line 795 = 39
# length of line 796 = 49
# length of line 797 = 42
# length of line 798 = 43
# length of line 799 = 41
# length of line 800 = 40
# length of line 801 = 41
# length of line 802 = 45
# length of line 803 = 45
# length of line 804 = 16
# length of line 805 = 1
# length of line 806 = 5
# length of line 807 = 25
# length of line 808 = 1
# length of line 809 = 5
# length of line 810 = 38
# length of line 811 = 1
# length of line 812 = 43
# length of line 813 = 1
# length of line 814 = 45
# length of line 815 = 51
# length of line 816 = 52
# length of line 817 = 52
# length of line 818 = 1
# length of line 819 = 8
# length of line 820 = 1
# length of line 821 = 1
# length of line 822 = 1
# length of line 823 = 39
# length of line 824 = 1
# length of line 825 = 29
# length of line 826 = 1
# length of line 827 = 6
# length of line 828 = 39
# length of line 829 = 39
# length of line 830 = 39
# length of line 831 = 26
# length of line 832 = 1
# length of line 833 = 5
# length of line 834 = 19
# length of line 835 = 1
# length of line 836 = 6
# length of line 837 = 44
# length of line 838 = 39
# length of line 839 = 39
# length of line 840 = 44
# length of line 841 = 40
# length of line 842 = 9
# length of line 843 = 1
# length of line 844 = 5
# length of line 845 = 16
# length of line 846 = 1
# length of line 847 = 6
# length of line 848 = 18
# length of line 849 = 42
# length of line 850 = 45
# length of line 851 = 40
# length of line 852 = 45
# length of line 853 = 41
# length of line 854 = 43
# length of line 855 = 48
# length of line 856 = 40
# length of line 857 = 36
# length of line 858 = 45
# length of line 859 = 43
# length of line 860 = 47
# length of line 861 = 41
# length of line 862 = 54
# length of line 863 = 41
# length of line 864 = 38
# length of line 865 = 46
# length of line 866 = 44
# length of line 867 = 45
# length of line 868 = 44
# length of line 869 = 49
# length of line 870 = 31
# length of line 871 = 43
# length of line 872 = 44
# length of line 873 = 38
# length of line 874 = 37
# length of line 875 = 38
# length of line 876 = 45
# length of line 877 = 43
# length of line 878 = 43
# length of line 879 = 40
# length of line 880 = 41
# length of line 881 = 40
# length of line 882 = 47
# length of line 883 = 1
# length of line 884 = 5
# length of line 885 = 44
# length of line 886 = 47
# length of line 887 = 39
# length of line 888 = 44
# length of line 889 = 46
# length of line 890 = 46
# length of line 891 = 28
# length of line 892 = 1
# length of line 893 = 6
# length of line 894 = 16
# length of line 895 = 44
# length of line 896 = 1
# length of line 897 = 18
# length of line 898 = 1
# length of line 899 = 37
# length of line 900 = 37
# length of line 901 = 1
# length of line 902 = 5
# length of line 903 = 46
# length of line 904 = 44
# length of line 905 = 55
# length of line 906 = 1
# length of line 907 = 37
# length of line 908 = 1
# length of line 909 = 37
# length of line 910 = 50
# length of line 911 = 40
# length of line 912 = 42
# length of line 913 = 51
# length of line 914 = 48
# length of line 915 = 44
# length of line 916 = 47
# length of line 917 = 41
# length of line 918 = 44
# length of line 919 = 45
# length of line 920 = 51
# length of line 921 = 39
# length of line 922 = 45
# length of line 923 = 39
# length of line 924 = 48
# length of line 925 = 44
# length of line 926 = 36
# length of line 927 = 43
# length of line 928 = 43
# length of line 929 = 44
# length of line 930 = 42
# length of line 931 = 41
# length of line 932 = 43
# length of line 933 = 1
# length of line 934 = 6
# length of line 935 = 41
# length of line 936 = 1
# length of line 937 = 5
# length of line 938 = 46
# length of line 939 = 1
# length of line 940 = 6
# length of line 941 = 37
# length of line 942 = 25
# length of line 943 = 1
# length of line 944 = 5
# length of line 945 = 26
# length of line 946 = 43
# length of line 947 = 1
# length of line 948 = 6
# length of line 949 = 10
# length of line 950 = 1
# length of line 951 = 8
# length of line 952 = 1
# length of line 953 = 5
# length of line 954 = 41
# length of line 955 = 1
# length of line 956 = 5
# length of line 957 = 51
# length of line 958 = 1
# length of line 959 = 5
# length of line 960 = 23
# length of line 961 = 38
# length of line 962 = 44
# length of line 963 = 52
# length of line 964 = 36
# length of line 965 = 45
# length of line 966 = 42
# length of line 967 = 44
# length of line 968 = 43
# length of line 969 = 1
# length of line 970 = 5
# length of line 971 = 44
# length of line 972 = 24
# length of line 973 = 1
# length of line 974 = 5
# length of line 975 = 46
# length of line 976 = 40
# length of line 977 = 46
# length of line 978 = 1
# length of line 979 = 5
# length of line 980 = 45
# length of line 981 = 1
# length of line 982 = 5
# length of line 983 = 46
# length of line 984 = 48
# length of line 985 = 53
# length of line 986 = 47
# length of line 987 = 44
# length of line 988 = 1
# length of line 989 = 5
# length of line 990 = 41
# length of line 991 = 23
# length of line 992 = 1
# length of line 993 = 5
# length of line 994 = 43
# length of line 995 = 1
# length of line 996 = 5
# length of line 997 = 51
# length of line 998 = 41
# length of line 999 = 1
# length of line 1000 = 5
# length of line 1001 = 44
# length of line 1002 = 44
# length of line 1003 = 47
# length of line 1004 = 47
# length of line 1005 = 44
# length of line 1006 = 43
# length of line 1007 = 46
# length of line 1008 = 39
# length of line 1009 = 43
# length of line 1010 = 42
# length of line 1011 = 37
# length of line 1012 = 40
# length of line 1013 = 49
# length of line 1014 = 46
# length of line 1015 = 38
# length of line 1016 = 43
# length of line 1017 = 42
# length of line 1018 = 50
# length of line 1019 = 39
# length of line 1020 = 47
# length of line 1021 = 41
# length of line 1022 = 1
# length of line 1023 = 5
# length of line 1024 = 23
# length of line 1025 = 1
# length of line 1026 = 10
# length of line 1027 = 1
# length of line 1028 = 1
# length of line 1029 = 1
# length of line 1030 = 24
# length of line 1031 = 1
# length of line 1032 = 40
# length of line 1033 = 1
# length of line 1034 = 5
# length of line 1035 = 41
# length of line 1036 = 1
# length of line 1037 = 5
# length of line 1038 = 34
# length of line 1039 = 1
# length of line 1040 = 5
# length of line 1041 = 15
# length of line 1042 = 1
# length of line 1043 = 5
# length of line 1044 = 28
# length of line 1045 = 1
# length of line 1046 = 5
# length of line 1047 = 18
# length of line 1048 = 1
# length of line 1049 = 5
# length of line 1050 = 51
# length of line 1051 = 42
# length of line 1052 = 1
# length of line 1053 = 56
# length of line 1054 = 1
# length of line 1055 = 30
# length of line 1056 = 1
# length of line 1057 = 5
# length of line 1058 = 49
# length of line 1059 = 51
# length of line 1060 = 48
# length of line 1061 = 42
# length of line 1062 = 27
# length of line 1063 = 1
# length of line 1064 = 5
# length of line 1065 = 16
# length of line 1066 = 1
# length of line 1067 = 5
# length of line 1068 = 17
# length of line 1069 = 42
# length of line 1070 = 40
# length of line 1071 = 49
# length of line 1072 = 38
# length of line 1073 = 46
# length of line 1074 = 49
# length of line 1075 = 41
# length of line 1076 = 51
# length of line 1077 = 38
# length of line 1078 = 36
# length of line 1079 = 47
# length of line 1080 = 49
# length of line 1081 = 41
# length of line 1082 = 38
# length of line 1083 = 49
# length of line 1084 = 45
# length of line 1085 = 49
# length of line 1086 = 42
# length of line 1087 = 44
# length of line 1088 = 47
# length of line 1089 = 34
# length of line 1090 = 45
# length of line 1091 = 45
# length of line 1092 = 41
# length of line 1093 = 20
# length of line 1094 = 1
# length of line 1095 = 5
# length of line 1096 = 25
# length of line 1097 = 1
# length of line 1098 = 15
# length of line 1099 = 1
# length of line 1100 = 5
# length of line 1101 = 43
# length of line 1102 = 45
# length of line 1103 = 54
# length of line 1104 = 37
# length of line 1105 = 41
# length of line 1106 = 50
# length of line 1107 = 40
# length of line 1108 = 40
# length of line 1109 = 43
# length of line 1110 = 47
# length of line 1111 = 38
# length of line 1112 = 40
# length of line 1113 = 43
# length of line 1114 = 48
# length of line 1115 = 42
# length of line 1116 = 45
# length of line 1117 = 37
# length of line 1118 = 47
# length of line 1119 = 48
# length of line 1120 = 1
# length of line 1121 = 24
# length of line 1122 = 1
# length of line 1123 = 5
# length of line 1124 = 35
# length of line 1125 = 36
# length of line 1126 = 14
# length of line 1127 = 1
# length of line 1128 = 5
# length of line 1129 = 32
# length of line 1130 = 39
# length of line 1131 = 23
# length of line 1132 = 1
# length of line 1133 = 5
# length of line 1134 = 17
# length of line 1135 = 1
# length of line 1136 = 5
# length of line 1137 = 42
# length of line 1138 = 1
# length of line 1139 = 5
# length of line 1140 = 17
# length of line 1141 = 1
# length of line 1142 = 5
# length of line 1143 = 30
# length of line 1144 = 37
# length of line 1145 = 41
# length of line 1146 = 34
# length of line 1147 = 42
# length of line 1148 = 1
# length of line 1149 = 5
# length of line 1150 = 48
# length of line 1151 = 39
# length of line 1152 = 41
# length of line 1153 = 42
# length of line 1154 = 48
# length of line 1155 = 40
# length of line 1156 = 41
# length of line 1157 = 38
# length of line 1158 = 37
# length of line 1159 = 27
# length of line 1160 = 1
# length of line 1161 = 5
# length of line 1162 = 21
# length of line 1163 = 25
# length of line 1164 = 1
# length of line 1165 = 5
# length of line 1166 = 27
# length of line 1167 = 1
# length of line 1168 = 5
# length of line 1169 = 21
# length of line 1170 = 1
# length of line 1171 = 5
# length of line 1172 = 28
# length of line 1173 = 1
# length of line 1174 = 5
# length of line 1175 = 19
# length of line 1176 = 41
# length of line 1177 = 39
# length of line 1178 = 1
# length of line 1179 = 17
# length of line 1180 = 1
# length of line 1181 = 44
# length of line 1182 = 1
# length of line 1183 = 27
# length of line 1184 = 1
# length of line 1185 = 52
# length of line 1186 = 39
# length of line 1187 = 1
# length of line 1188 = 27
# length of line 1189 = 1
# length of line 1190 = 5
# length of line 1191 = 37
# length of line 1192 = 1
# length of line 1193 = 5
# length of line 1194 = 45
# length of line 1195 = 1
# length of line 1196 = 5
# length of line 1197 = 43
# length of line 1198 = 1
# length of line 1199 = 5
# length of line 1200 = 45
# length of line 1201 = 1
# length of line 1202 = 5
# length of line 1203 = 23
# length of line 1204 = 1
# length of line 1205 = 5
# length of line 1206 = 23
# length of line 1207 = 1
# length of line 1208 = 10
# length of line 1209 = 1
# length of line 1210 = 1
# length of line 1211 = 1
# length of line 1212 = 43
# length of line 1213 = 1
# length of line 1214 = 26
# length of line 1215 = 1
# length of line 1216 = 5
# length of line 1217 = 54
# length of line 1218 = 1
# length of line 1219 = 7
# length of line 1220 = 9
# length of line 1221 = 1
# length of line 1222 = 5
# length of line 1223 = 8
# length of line 1224 = 1
# length of line 1225 = 7
# length of line 1226 = 24
# length of line 1227 = 43
# length of line 1228 = 23
# length of line 1229 = 1
# length of line 1230 = 5
# length of line 1231 = 18
# length of line 1232 = 1
# length of line 1233 = 7
# length of line 1234 = 42
# length of line 1235 = 24
# length of line 1236 = 1
# length of line 1237 = 5
# length of line 1238 = 27
# length of line 1239 = 1
# length of line 1240 = 7
# length of line 1241 = 46
# length of line 1242 = 1
# length of line 1243 = 5
# length of line 1244 = 6
# length of line 1245 = 1
# length of line 1246 = 7
# length of line 1247 = 26
# length of line 1248 = 45
# length of line 1249 = 43
# length of line 1250 = 47
# length of line 1251 = 48
# length of line 1252 = 40
# length of line 1253 = 42
# length of line 1254 = 50
# length of line 1255 = 57
# length of line 1256 = 40
# length of line 1257 = 41
# length of line 1258 = 40
# length of line 1259 = 36
# length of line 1260 = 52
# length of line 1261 = 42
# length of line 1262 = 1
# length of line 1263 = 5
# length of line 1264 = 7
# length of line 1265 = 1
# length of line 1266 = 7
# length of line 1267 = 44
# length of line 1268 = 1
# length of line 1269 = 5
# length of line 1270 = 8
# length of line 1271 = 1
# length of line 1272 = 7
# length of line 1273 = 40
# length of line 1274 = 44
# length of line 1275 = 1
# length of line 1276 = 5
# length of line 1277 = 48
# length of line 1278 = 39
# length of line 1279 = 25
# length of line 1280 = 1
# length of line 1281 = 7
# length of line 1282 = 17
# length of line 1283 = 46
# length of line 1284 = 41
# length of line 1285 = 50
# length of line 1286 = 45
# length of line 1287 = 48
# length of line 1288 = 35
# length of line 1289 = 43
# length of line 1290 = 45
# length of line 1291 = 21
# length of line 1292 = 1
# length of line 1293 = 5
# length of line 1294 = 21
# length of line 1295 = 12
# length of line 1296 = 1
# length of line 1297 = 7
# length of line 1298 = 44
# length of line 1299 = 53
# length of line 1300 = 44
# length of line 1301 = 40
# length of line 1302 = 44
# length of line 1303 = 40
# length of line 1304 = 40
# length of line 1305 = 44
# length of line 1306 = 42
# length of line 1307 = 44
# length of line 1308 = 18
# length of line 1309 = 39
# length of line 1310 = 47
# length of line 1311 = 43
# length of line 1312 = 36
# length of line 1313 = 21
# length of line 1314 = 44
# length of line 1315 = 46
# length of line 1316 = 35
# length of line 1317 = 37
# length of line 1318 = 40
# length of line 1319 = 39
# length of line 1320 = 38
# length of line 1321 = 39
# length of line 1322 = 47
# length of line 1323 = 42
# length of line 1324 = 40
# length of line 1325 = 42
# length of line 1326 = 46
# length of line 1327 = 40
# length of line 1328 = 47
# length of line 1329 = 20
# length of line 1330 = 43
# length of line 1331 = 49
# length of line 1332 = 40
# length of line 1333 = 36
# length of line 1334 = 42
# length of line 1335 = 38
# length of line 1336 = 41
# length of line 1337 = 42
# length of line 1338 = 36
# length of line 1339 = 38
# length of line 1340 = 39
# length of line 1341 = 46
# length of line 1342 = 47
# length of line 1343 = 45
# length of line 1344 = 48
# length of line 1345 = 41
# length of line 1346 = 40
# length of line 1347 = 35
# length of line 1348 = 1
# length of line 1349 = 8
# length of line 1350 = 1
# length of line 1351 = 5
# length of line 1352 = 46
# length of line 1353 = 50
# length of line 1354 = 42
# length of line 1355 = 40
# length of line 1356 = 47
# length of line 1357 = 41
# length of line 1358 = 33
# length of line 1359 = 41
# length of line 1360 = 50
# length of line 1361 = 41
# length of line 1362 = 41
# length of line 1363 = 40
# length of line 1364 = 45
# length of line 1365 = 25
# length of line 1366 = 45
# length of line 1367 = 38
# length of line 1368 = 49
# length of line 1369 = 46
# length of line 1370 = 1
# length of line 1371 = 11
# length of line 1372 = 1
# length of line 1373 = 42
# length of line 1374 = 35
# length of line 1375 = 16
# length of line 1376 = 1
# length of line 1377 = 5
# length of line 1378 = 30
# length of line 1379 = 1
# length of line 1380 = 5
# length of line 1381 = 25
# length of line 1382 = 1
# length of line 1383 = 5
# length of line 1384 = 29
# length of line 1385 = 1
# length of line 1386 = 5
# length of line 1387 = 10
# length of line 1388 = 1
# length of line 1389 = 5
# length of line 1390 = 33
# length of line 1391 = 1
# length of line 1392 = 5
# length of line 1393 = 38
# length of line 1394 = 1
# length of line 1395 = 31
# length of line 1396 = 1
# length of line 1397 = 5
# length of line 1398 = 25
# length of line 1399 = 1
# length of line 1400 = 5
# length of line 1401 = 20
# length of line 1402 = 1
# length of line 1403 = 5
# length of line 1404 = 14
# length of line 1405 = 1
# length of line 1406 = 5
# length of line 1407 = 23
# length of line 1408 = 1
# length of line 1409 = 5
# length of line 1410 = 22
# length of line 1411 = 1
# length of line 1412 = 5
# length of line 1413 = 27
# length of line 1414 = 1
# length of line 1415 = 5
# length of line 1416 = 16
# length of line 1417 = 1
# length of line 1418 = 5
# length of line 1419 = 54
# length of line 1420 = 22
# length of line 1421 = 1
# length of line 1422 = 14
# length of line 1423 = 24
# length of line 1424 = 1
# length of line 1425 = 5
# length of line 1426 = 48
# length of line 1427 = 26
# length of line 1428 = 1
# length of line 1429 = 5
# length of line 1430 = 51
# length of line 1431 = 17
# length of line 1432 = 1
# length of line 1433 = 5
# length of line 1434 = 34
# length of line 1435 = 42
# length of line 1436 = 44
# length of line 1437 = 53
# length of line 1438 = 40
# length of line 1439 = 42
# length of line 1440 = 24
# length of line 1441 = 1
# length of line 1442 = 5
# length of line 1443 = 48
# length of line 1444 = 1
# length of line 1445 = 5
# length of line 1446 = 37
# length of line 1447 = 22
# length of line 1448 = 1
# length of line 1449 = 5
# length of line 1450 = 29
# length of line 1451 = 1
# length of line 1452 = 5
# length of line 1453 = 46
# length of line 1454 = 51
# length of line 1455 = 45
# length of line 1456 = 44
# length of line 1457 = 48
# length of line 1458 = 44
# length of line 1459 = 26
# length of line 1460 = 1
# length of line 1461 = 5
# length of line 1462 = 29
# length of line 1463 = 1
# length of line 1464 = 5
# length of line 1465 = 46
# length of line 1466 = 1
# length of line 1467 = 14
# length of line 1468 = 22
# length of line 1469 = 1
# length of line 1470 = 5
# length of line 1471 = 18
# length of line 1472 = 1
# length of line 1473 = 5
# length of line 1474 = 10
# length of line 1475 = 16
# length of line 1476 = 1
# length of line 1477 = 5
# length of line 1478 = 26
# length of line 1479 = 1
# length of line 1480 = 5
# length of line 1481 = 15
# length of line 1482 = 1
# length of line 1483 = 5
# length of line 1484 = 33
# length of line 1485 = 1
# length of line 1486 = 5
# length of line 1487 = 31
# length of line 1488 = 1
# length of line 1489 = 7
# length of line 1490 = 18
# length of line 1491 = 1
# length of line 1492 = 5
# length of line 1493 = 57
# length of line 1494 = 51
# length of line 1495 = 18
# length of line 1496 = 1
# length of line 1497 = 5
# length of line 1498 = 27
# length of line 1499 = 1
# length of line 1500 = 5
# length of line 1501 = 43
# length of line 1502 = 19
# length of line 1503 = 1
# length of line 1504 = 7
# length of line 1505 = 18
# length of line 1506 = 1
# length of line 1507 = 5
# length of line 1508 = 46
# length of line 1509 = 24
# length of line 1510 = 40
# length of line 1511 = 44
# length of line 1512 = 19
# length of line 1513 = 1
# length of line 1514 = 7
# length of line 1515 = 18
# length of line 1516 = 1
# length of line 1517 = 5
# length of line 1518 = 54
# length of line 1519 = 50
# length of line 1520 = 1
# length of line 1521 = 5
# length of line 1522 = 47
# length of line 1523 = 1
# length of line 1524 = 5
# length of line 1525 = 45
# length of line 1526 = 52
# length of line 1527 = 39
# length of line 1528 = 12
# length of line 1529 = 43
# length of line 1530 = 43
# length of line 1531 = 44
# length of line 1532 = 34
# length of line 1533 = 48
# length of line 1534 = 47
# length of line 1535 = 43
# length of line 1536 = 59
# length of line 1537 = 61
# length of line 1538 = 38
# length of line 1539 = 47
# length of line 1540 = 47
# length of line 1541 = 7
# length of line 1542 = 1
# length of line 1543 = 7
# length of line 1544 = 18
# length of line 1545 = 1
# length of line 1546 = 5
# length of line 1547 = 46
# length of line 1548 = 41
# length of line 1549 = 36
# length of line 1550 = 50
# length of line 1551 = 52
# length of line 1552 = 45
# length of line 1553 = 43
# length of line 1554 = 40
# length of line 1555 = 30
# length of line 1556 = 1
# length of line 1557 = 10
# length of line 1558 = 1
# length of line 1559 = 1
# length of line 1560 = 1
# length of line 1561 = 8
# length of line 1562 = 1
# length of line 1563 = 37
# length of line 1564 = 1
# length of line 1565 = 31
# length of line 1566 = 1
# length of line 1567 = 5
# length of line 1568 = 47
# length of line 1569 = 1
# length of line 1570 = 5
# length of line 1571 = 17
# length of line 1572 = 1
# length of line 1573 = 5
# length of line 1574 = 47
# length of line 1575 = 38
# length of line 1576 = 18
# length of line 1577 = 1
# length of line 1578 = 5
# length of line 1579 = 26
# length of line 1580 = 1
# length of line 1581 = 5
# length of line 1582 = 49
# length of line 1583 = 45
# length of line 1584 = 51
# length of line 1585 = 44
# length of line 1586 = 45
# length of line 1587 = 47
# length of line 1588 = 44
# length of line 1589 = 52
# length of line 1590 = 45
# length of line 1591 = 46
# length of line 1592 = 1
# length of line 1593 = 5
# length of line 1594 = 24
# length of line 1595 = 1
# length of line 1596 = 5
# length of line 1597 = 49
# length of line 1598 = 39
# length of line 1599 = 42
# length of line 1600 = 47
# length of line 1601 = 41
# length of line 1602 = 45
# length of line 1603 = 39
# length of line 1604 = 22
# length of line 1605 = 1
# length of line 1606 = 5
# length of line 1607 = 20
# length of line 1608 = 1
# length of line 1609 = 5
# length of line 1610 = 49
# length of line 1611 = 30
# length of line 1612 = 1
# length of line 1613 = 5
# length of line 1614 = 35
# length of line 1615 = 1
# length of line 1616 = 5
# length of line 1617 = 47
# length of line 1618 = 41
# length of line 1619 = 33
# length of line 1620 = 58
# length of line 1621 = 42
# length of line 1622 = 40
# length of line 1623 = 35
# length of line 1624 = 20
# length of line 1625 = 1
# length of line 1626 = 5
# length of line 1627 = 21
# length of line 1628 = 1
# length of line 1629 = 5
# length of line 1630 = 30
# length of line 1631 = 1
# length of line 1632 = 5
# length of line 1633 = 13
# length of line 1634 = 19
# length of line 1635 = 1
# length of line 1636 = 5
# length of line 1637 = 29
# length of line 1638 = 40
# length of line 1639 = 42
# length of line 1640 = 50
# length of line 1641 = 10
# length of line 1642 = 45
# length of line 1643 = 43
# length of line 1644 = 44
# length of line 1645 = 40
# length of line 1646 = 49
# length of line 1647 = 40
# length of line 1648 = 20
# length of line 1649 = 1
# length of line 1650 = 5
# length of line 1651 = 20
# length of line 1652 = 1
# length of line 1653 = 5
# length of line 1654 = 66
# length of line 1655 = 63
# length of line 1656 = 1
# length of line 1657 = 5
# length of line 1658 = 55
# length of line 1659 = 12
# length of line 1660 = 1
# length of line 1661 = 5
# length of line 1662 = 43
# length of line 1663 = 49
# length of line 1664 = 37
# length of line 1665 = 55
# length of line 1666 = 48
# length of line 1667 = 44
# length of line 1668 = 42
# length of line 1669 = 38
# length of line 1670 = 13
# length of line 1671 = 49
# length of line 1672 = 39
# length of line 1673 = 41
# length of line 1674 = 37
# length of line 1675 = 37
# length of line 1676 = 45
# length of line 1677 = 1
# length of line 1678 = 5
# length of line 1679 = 17
# length of line 1680 = 1
# length of line 1681 = 5
# length of line 1682 = 31
# length of line 1683 = 1
# length of line 1684 = 5
# length of line 1685 = 14
# length of line 1686 = 1
# length of line 1687 = 5
# length of line 1688 = 37
# length of line 1689 = 1
# length of line 1690 = 5
# length of line 1691 = 18
# length of line 1692 = 1
# length of line 1693 = 5
# length of line 1694 = 27
# length of line 1695 = 1
# length of line 1696 = 5
# length of line 1697 = 15
# length of line 1698 = 1
# length of line 1699 = 5
# length of line 1700 = 10
# length of line 1701 = 1
# length of line 1702 = 17
# length of line 1703 = 1
# length of line 1704 = 17
# length of line 1705 = 1
# length of line 1706 = 37
# length of line 1707 = 1
# length of line 1708 = 5
# length of line 1709 = 42
# length of line 1710 = 1
# length of line 1711 = 5
# length of line 1712 = 31
# length of line 1713 = 1
# length of line 1714 = 5
# length of line 1715 = 40
# length of line 1716 = 45
# length of line 1717 = 44
# length of line 1718 = 41
# length of line 1719 = 50
# length of line 1720 = 38
# length of line 1721 = 37
# length of line 1722 = 42
# length of line 1723 = 1
# length of line 1724 = 5
# length of line 1725 = 18
# length of line 1726 = 1
# length of line 1727 = 5
# length of line 1728 = 24
# length of line 1729 = 24
# length of line 1730 = 1
# length of line 1731 = 5
# length of line 1732 = 14
# length of line 1733 = 1
# length of line 1734 = 5
# length of line 1735 = 43
# length of line 1736 = 43
# length of line 1737 = 44
# length of line 1738 = 36
# length of line 1739 = 40
# length of line 1740 = 40
# length of line 1741 = 47
# length of line 1742 = 41
# length of line 1743 = 39
# length of line 1744 = 45
# length of line 1745 = 44
# length of line 1746 = 44
# length of line 1747 = 45
# length of line 1748 = 42
# length of line 1749 = 1
# length of line 1750 = 5
# length of line 1751 = 43
# length of line 1752 = 34
# length of line 1753 = 39
# length of line 1754 = 46
# length of line 1755 = 35
# length of line 1756 = 45
# length of line 1757 = 49
# length of line 1758 = 1
# length of line 1759 = 5
# length of line 1760 = 43
# length of line 1761 = 35
# length of line 1762 = 18
# length of line 1763 = 1
# length of line 1764 = 5
# length of line 1765 = 24
# length of line 1766 = 46
# length of line 1767 = 50
# length of line 1768 = 50
# length of line 1769 = 33
# length of line 1770 = 41
# length of line 1771 = 37
# length of line 1772 = 45
# length of line 1773 = 56
# length of line 1774 = 44
# length of line 1775 = 1
# length of line 1776 = 10
# length of line 1777 = 1
# length of line 1778 = 1
# length of line 1779 = 1
# length of line 1780 = 32
# length of line 1781 = 1
# length of line 1782 = 57
# length of line 1783 = 1
# length of line 1784 = 6
# length of line 1785 = 44
# length of line 1786 = 43
# length of line 1787 = 40
# length of line 1788 = 44
# length of line 1789 = 42
# length of line 1790 = 42
# length of line 1791 = 42
# length of line 1792 = 53
# length of line 1793 = 43
# length of line 1794 = 38
# length of line 1795 = 50
# length of line 1796 = 50
# length of line 1797 = 47
# length of line 1798 = 39
# length of line 1799 = 44
# length of line 1800 = 40
# length of line 1801 = 49
# length of line 1802 = 38
# length of line 1803 = 1
# length of line 1804 = 7
# length of line 1805 = 44
# length of line 1806 = 43
# length of line 1807 = 47
# length of line 1808 = 40
# length of line 1809 = 39
# length of line 1810 = 39
# length of line 1811 = 42
# length of line 1812 = 30
# length of line 1813 = 1
# length of line 1814 = 5
# length of line 1815 = 20
# length of line 1816 = 46
# length of line 1817 = 43
# length of line 1818 = 18
# length of line 1819 = 1
# length of line 1820 = 6
# length of line 1821 = 14
# length of line 1822 = 46
# length of line 1823 = 40
# length of line 1824 = 17
# length of line 1825 = 1
# length of line 1826 = 6
# length of line 1827 = 45
# length of line 1828 = 1
# length of line 1829 = 7
# length of line 1830 = 45
# length of line 1831 = 37
# length of line 1832 = 43
# length of line 1833 = 43
# length of line 1834 = 1
# length of line 1835 = 6
# length of line 1836 = 44
# length of line 1837 = 29
# length of line 1838 = 1
# length of line 1839 = 7
# length of line 1840 = 10
# length of line 1841 = 1
# length of line 1842 = 57
# length of line 1843 = 1
# length of line 1844 = 18
# length of line 1845 = 1
# length of line 1846 = 5
# length of line 1847 = 43
# length of line 1848 = 23
# length of line 1849 = 1
# length of line 1850 = 6
# length of line 1851 = 46
# length of line 1852 = 1
# length of line 1853 = 5
# length of line 1854 = 44
# length of line 1855 = 35
# length of line 1856 = 40
# length of line 1857 = 44
# length of line 1858 = 38
# length of line 1859 = 42
# length of line 1860 = 35
# length of line 1861 = 1
# length of line 1862 = 6
# length of line 1863 = 42
# length of line 1864 = 1
# length of line 1865 = 5
# length of line 1866 = 42
# length of line 1867 = 48
# length of line 1868 = 1
# length of line 1869 = 6
# length of line 1870 = 45
# length of line 1871 = 1
# length of line 1872 = 17
# length of line 1873 = 1
# length of line 1874 = 43
# length of line 1875 = 49
# length of line 1876 = 1
# length of line 1877 = 7
# length of line 1878 = 39
# length of line 1879 = 47
# length of line 1880 = 1
# length of line 1881 = 6
# length of line 1882 = 25
# length of line 1883 = 1
# length of line 1884 = 48
# length of line 1885 = 1
# length of line 1886 = 26
# length of line 1887 = 46
# length of line 1888 = 1
# length of line 1889 = 6
# length of line 1890 = 43
# length of line 1891 = 40
# length of line 1892 = 43
# length of line 1893 = 40
# length of line 1894 = 40
# length of line 1895 = 49
# length of line 1896 = 41
# length of line 1897 = 46
# length of line 1898 = 42
# length of line 1899 = 43
# length of line 1900 = 38
# length of line 1901 = 48
# length of line 1902 = 39
# length of line 1903 = 47
# length of line 1904 = 45
# length of line 1905 = 41
# length of line 1906 = 40
# length of line 1907 = 17
# length of line 1908 = 44
# length of line 1909 = 44
# length of line 1910 = 40
# length of line 1911 = 25
# length of line 1912 = 1
# length of line 1913 = 6
# length of line 1914 = 18
# length of line 1915 = 44
# length of line 1916 = 38
# length of line 1917 = 49
# length of line 1918 = 48
# length of line 1919 = 19
# length of line 1920 = 1
# length of line 1921 = 34
# length of line 1922 = 1
# length of line 1923 = 5
# length of line 1924 = 31
# length of line 1925 = 37
# length of line 1926 = 38
# length of line 1927 = 50
# length of line 1928 = 48
# length of line 1929 = 45
# length of line 1930 = 50
# length of line 1931 = 41
# length of line 1932 = 43
# length of line 1933 = 42
# length of line 1934 = 17
# length of line 1935 = 1
# length of line 1936 = 7
# length of line 1937 = 28
# length of line 1938 = 1
# length of line 1939 = 5
# length of line 1940 = 36
# length of line 1941 = 48
# length of line 1942 = 43
# length of line 1943 = 40
# length of line 1944 = 43
# length of line 1945 = 43
# length of line 1946 = 41
# length of line 1947 = 42
# length of line 1948 = 41
# length of line 1949 = 9
# length of line 1950 = 47
# length of line 1951 = 38
# length of line 1952 = 45
# length of line 1953 = 9
# length of line 1954 = 59
# length of line 1955 = 12
# length of line 1956 = 60
# length of line 1957 = 34
# length of line 1958 = 9
# length of line 1959 = 43
# length of line 1960 = 1
# length of line 1961 = 7
# length of line 1962 = 30
# length of line 1963 = 1
# length of line 1964 = 5
# length of line 1965 = 45
# length of line 1966 = 9
# length of line 1967 = 34
# length of line 1968 = 35
# length of line 1969 = 29
# length of line 1970 = 29
# length of line 1971 = 62
# length of line 1972 = 66
# length of line 1973 = 11
# length of line 1974 = 66
# length of line 1975 = 14
# length of line 1976 = 48
# length of line 1977 = 38
# length of line 1978 = 47
# length of line 1979 = 23
# length of line 1980 = 1
# length of line 1981 = 6
# length of line 1982 = 17
# length of line 1983 = 19
# length of line 1984 = 1
# length of line 1985 = 5
# length of line 1986 = 25
# length of line 1987 = 1
# length of line 1988 = 6
# length of line 1989 = 37
# length of line 1990 = 1
# length of line 1991 = 5
# length of line 1992 = 49
# length of line 1993 = 45
# ...
# length of line 6120 = 17
# length of line 6121 = 1
# length of line 6122 = 5
# length of line 6123 = 45
# length of line 6124 = 41
# length of line 6125 = 1
# length of line 6126 = 5
# length of line 6127 = 39
# length of line 6128 = 45
# length of line 6129 = 35
# length of line 6130 = 33
# length of line 6131 = 35
# length of line 6132 = 48
# length of line 6133 = 47
# length of line 6134 = 25
# length of line 6135 = 1
# length of line 6136 = 5
# length of line 6137 = 23
# length of line 6138 = 1
# length of line 6139 = 15
# length of line 6140 = 1
# length of line 6141 = 5
# length of line 6142 = 48
# length of line 6143 = 1
# length of line 6144 = 5
# length of line 6145 = 51
# length of line 6146 = 1
# length of line 6147 = 5
# length of line 6148 = 18
# length of line 6149 = 1
# length of line 6150 = 5
# length of line 6151 = 64
# length of line 6152 = 64
# length of line 6153 = 66
# length of line 6154 = 41
# length of line 6155 = 1
# length of line 6156 = 5
# length of line 6157 = 55
# length of line 6158 = 40
# length of line 6159 = 1
# length of line 6160 = 5
# length of line 6161 = 57
# length of line 6162 = 44
# length of line 6163 = 1
# length of line 6164 = 5
# length of line 6165 = 38
# length of line 6166 = 1
# length of line 6167 = 5
# length of line 6168 = 55
# length of line 6169 = 1
# length of line 6170 = 5
# length of line 6171 = 41
# length of line 6172 = 1
# length of line 6173 = 5
# length of line 6174 = 54
# length of line 6175 = 1
# length of line 6176 = 5
# length of line 6177 = 62
# length of line 6178 = 64
# length of line 6179 = 57
# length of line 6180 = 10
# length of line 6181 = 1
# length of line 6182 = 5
# length of line 6183 = 27
# length of line 6184 = 38
# length of line 6185 = 1
# length of line 6186 = 5
# length of line 6187 = 60
# length of line 6188 = 56
# length of line 6189 = 60
# length of line 6190 = 65
# length of line 6191 = 65
# length of line 6192 = 46
# length of line 6193 = 1
# length of line 6194 = 5
# length of line 6195 = 60
# length of line 6196 = 64
# length of line 6197 = 63
# length of line 6198 = 66
# length of line 6199 = 66
# length of line 6200 = 63
# length of line 6201 = 44
# length of line 6202 = 1
# length of line 6203 = 5
# length of line 6204 = 45
# length of line 6205 = 1
# length of line 6206 = 5
# length of line 6207 = 63
# length of line 6208 = 14
# length of line 6209 = 1
# length of line 6210 = 5
# length of line 6211 = 5
# length of line 6212 = 1
# length of line 6213 = 5
# length of line 6214 = 66
# length of line 6215 = 13
# length of line 6216 = 1
# length of line 6217 = 5
# length of line 6218 = 47
# length of line 6219 = 1
# length of line 6220 = 5
# length of line 6221 = 12
# length of line 6222 = 1
# length of line 6223 = 5
# length of line 6224 = 58
# length of line 6225 = 1
# length of line 6226 = 5
# length of line 6227 = 13
# length of line 6228 = 1
# length of line 6229 = 5
# length of line 6230 = 32
# length of line 6231 = 1
# length of line 6232 = 5
# length of line 6233 = 62
# length of line 6234 = 29
# length of line 6235 = 1
# length of line 6236 = 5
# length of line 6237 = 54
# length of line 6238 = 1
# length of line 6239 = 5
# length of line 6240 = 59
# length of line 6241 = 57
# length of line 6242 = 1
# length of line 6243 = 5
# length of line 6244 = 59
# length of line 6245 = 42
# length of line 6246 = 1
# length of line 6247 = 5
# length of line 6248 = 19
# length of line 6249 = 1
# length of line 6250 = 5
# length of line 6251 = 19
# length of line 6252 = 1
# length of line 6253 = 5
# length of line 6254 = 38
# length of line 6255 = 1
# length of line 6256 = 5
# length of line 6257 = 57
# length of line 6258 = 59
# length of line 6259 = 66
# length of line 6260 = 62
# length of line 6261 = 62
# length of line 6262 = 22
# length of line 6263 = 1
# length of line 6264 = 5
# length of line 6265 = 29
# length of line 6266 = 1
# length of line 6267 = 5
# length of line 6268 = 60
# length of line 6269 = 1
# length of line 6270 = 5
# length of line 6271 = 37
# length of line 6272 = 1
# length of line 6273 = 5
# length of line 6274 = 58
# length of line 6275 = 66
# length of line 6276 = 61
# length of line 6277 = 66
# length of line 6278 = 65
# length of line 6279 = 1
# length of line 6280 = 5
# length of line 6281 = 57
# length of line 6282 = 58
# length of line 6283 = 62
# length of line 6284 = 45
# length of line 6285 = 1
# length of line 6286 = 5
# length of line 6287 = 20
# length of line 6288 = 1
# length of line 6289 = 5
# length of line 6290 = 57
# length of line 6291 = 1
# length of line 6292 = 5
# length of line 6293 = 61
# length of line 6294 = 58
# length of line 6295 = 63
# length of line 6296 = 64
# length of line 6297 = 24
# length of line 6298 = 1
# length of line 6299 = 5
# length of line 6300 = 32
# length of line 6301 = 1
# length of line 6302 = 5
# length of line 6303 = 59
# length of line 6304 = 1
# length of line 6305 = 5
# length of line 6306 = 36
# length of line 6307 = 1
# length of line 6308 = 5
# length of line 6309 = 14
# length of line 6310 = 1
# length of line 6311 = 14
# length of line 6312 = 1
# length of line 6313 = 62
# length of line 6314 = 12
# length of line 6315 = 1
# length of line 6316 = 5
# length of line 6317 = 51
# length of line 6318 = 1
# length of line 6319 = 5
# length of line 6320 = 66
# length of line 6321 = 66
# length of line 6322 = 62
# length of line 6323 = 59
# length of line 6324 = 63
# length of line 6325 = 42
# length of line 6326 = 1
# length of line 6327 = 16
# length of line 6328 = 1
# length of line 6329 = 6
# length of line 6330 = 58
# length of line 6331 = 65
# length of line 6332 = 64
# length of line 6333 = 23
# length of line 6334 = 1
# length of line 6335 = 5
# length of line 6336 = 63
# length of line 6337 = 66
# length of line 6338 = 21
# length of line 6339 = 1
# length of line 6340 = 6
# length of line 6341 = 44
# length of line 6342 = 1
# length of line 6343 = 5
# length of line 6344 = 15
# length of line 6345 = 1
# length of line 6346 = 6
# length of line 6347 = 58
# length of line 6348 = 33
# length of line 6349 = 1
# length of line 6350 = 5
# length of line 6351 = 23
# length of line 6352 = 1
# length of line 6353 = 13
# length of line 6354 = 1
# length of line 6355 = 5
# length of line 6356 = 35
# length of line 6357 = 1
# length of line 6358 = 5
# length of line 6359 = 60
# length of line 6360 = 66
# length of line 6361 = 62
# length of line 6362 = 1
# length of line 6363 = 5
# length of line 6364 = 21
# length of line 6365 = 1
# length of line 6366 = 5
# length of line 6367 = 59
# length of line 6368 = 31
# length of line 6369 = 1
# length of line 6370 = 5
# length of line 6371 = 63
# length of line 6372 = 40
# length of line 6373 = 1
# length of line 6374 = 5
# length of line 6375 = 60
# length of line 6376 = 64
# length of line 6377 = 65
# length of line 6378 = 64
# length of line 6379 = 28
# length of line 6380 = 1
# length of line 6381 = 63
# length of line 6382 = 11
# length of line 6383 = 1
# length of line 6384 = 6
# length of line 6385 = 48
# length of line 6386 = 1
# length of line 6387 = 45
# length of line 6388 = 1
# length of line 6389 = 5
# length of line 6390 = 49
# length of line 6391 = 38
# length of line 6392 = 52
# length of line 6393 = 41
# length of line 6394 = 17
# length of line 6395 = 46
# length of line 6396 = 44
# length of line 6397 = 44
# length of line 6398 = 38
# length of line 6399 = 46
# length of line 6400 = 43
# length of line 6401 = 44
# length of line 6402 = 42
# length of line 6403 = 36
# length of line 6404 = 23
# length of line 6405 = 40
# length of line 6406 = 46
# length of line 6407 = 41
# length of line 6408 = 21
# length of line 6409 = 1
# length of line 6410 = 6
# length of line 6411 = 26
# length of line 6412 = 48
# length of line 6413 = 41
# length of line 6414 = 41
# length of line 6415 = 43
# length of line 6416 = 38
# length of line 6417 = 44
# length of line 6418 = 42
# length of line 6419 = 23
# length of line 6420 = 1
# length of line 6421 = 5
# length of line 6422 = 21
# length of line 6423 = 46
# length of line 6424 = 28
# length of line 6425 = 1
# length of line 6426 = 6
# length of line 6427 = 18
# length of line 6428 = 1
# length of line 6429 = 5
# length of line 6430 = 46
# length of line 6431 = 52
# length of line 6432 = 24
# length of line 6433 = 1
# length of line 6434 = 6
# length of line 6435 = 18
# length of line 6436 = 1
# length of line 6437 = 5
# length of line 6438 = 18
# length of line 6439 = 1
# length of line 6440 = 6
# length of line 6441 = 49
# length of line 6442 = 20
# length of line 6443 = 1
# length of line 6444 = 5
# length of line 6445 = 20
# length of line 6446 = 49
# length of line 6447 = 1
# length of line 6448 = 6
# length of line 6449 = 40
# length of line 6450 = 49
# length of line 6451 = 1
# length of line 6452 = 6
# length of line 6453 = 39
# length of line 6454 = 1
# length of line 6455 = 5
# length of line 6456 = 51
# length of line 6457 = 1
# length of line 6458 = 24
# length of line 6459 = 1
# length of line 6460 = 5
# length of line 6461 = 18
# length of line 6462 = 1
# length of line 6463 = 6
# length of line 6464 = 45
# length of line 6465 = 40
# length of line 6466 = 41
# length of line 6467 = 45
# length of line 6468 = 48
# length of line 6469 = 40
# length of line 6470 = 45
# length of line 6471 = 48
# length of line 6472 = 41
# length of line 6473 = 38
# length of line 6474 = 50
# length of line 6475 = 49
# length of line 6476 = 38
# length of line 6477 = 1
# length of line 6478 = 5
# length of line 6479 = 14
# length of line 6480 = 1
# length of line 6481 = 6
# length of line 6482 = 15
# length of line 6483 = 1
# length of line 6484 = 13
# length of line 6485 = 1
# length of line 6486 = 5
# length of line 6487 = 5
# length of line 6488 = 1
# length of line 6489 = 6
# length of line 6490 = 4
# length of line 6491 = 1
# length of line 6492 = 5
# length of line 6493 = 10
# length of line 6494 = 1
# length of line 6495 = 5
# length of line 6496 = 28
# length of line 6497 = 1
# length of line 6498 = 6
# length of line 6499 = 14
# length of line 6500 = 1
# length of line 6501 = 6
# length of line 6502 = 51
# length of line 6503 = 24
# length of line 6504 = 1
# length of line 6505 = 46
# length of line 6506 = 1
# length of line 6507 = 18
# length of line 6508 = 1
# length of line 6509 = 5
# length of line 6510 = 47
# length of line 6511 = 34
# length of line 6512 = 1
# length of line 6513 = 13
# length of line 6514 = 1
# length of line 6515 = 6
# length of line 6516 = 32
# length of line 6517 = 1
# length of line 6518 = 6
# length of line 6519 = 19
# length of line 6520 = 1
# length of line 6521 = 7
# length of line 6522 = 33
# length of line 6523 = 45
# length of line 6524 = 43
# length of line 6525 = 1
# length of line 6526 = 5
# length of line 6527 = 12
# length of line 6528 = 1
# length of line 6529 = 6
# length of line 6530 = 24
# length of line 6531 = 1
# length of line 6532 = 7
# length of line 6533 = 39
# length of line 6534 = 1
# length of line 6535 = 6
# length of line 6536 = 49
# length of line 6537 = 1
# length of line 6538 = 5
# length of line 6539 = 40
# length of line 6540 = 1
# length of line 6541 = 7
# length of line 6542 = 28
# length of line 6543 = 1
# length of line 6544 = 6
# length of line 6545 = 27
# length of line 6546 = 1
# length of line 6547 = 6
# length of line 6548 = 18
# length of line 6549 = 1
# length of line 6550 = 6
# length of line 6551 = 52
# length of line 6552 = 1
# length of line 6553 = 5
# length of line 6554 = 45
# length of line 6555 = 41
# length of line 6556 = 37
# length of line 6557 = 1
# length of line 6558 = 6
# length of line 6559 = 21
# length of line 6560 = 1
# length of line 6561 = 13
# length of line 6562 = 1
# length of line 6563 = 5
# length of line 6564 = 22
# length of line 6565 = 1
# length of line 6566 = 6
# length of line 6567 = 17
# length of line 6568 = 1
# length of line 6569 = 49
# length of line 6570 = 44
# length of line 6571 = 1
# length of line 6572 = 6
# length of line 6573 = 30
# length of line 6574 = 1
# length of line 6575 = 5
# length of line 6576 = 17
# length of line 6577 = 1
# length of line 6578 = 19
# length of line 6579 = 1
# length of line 6580 = 5
# length of line 6581 = 29
# length of line 6582 = 1
# length of line 6583 = 5
# length of line 6584 = 47
# length of line 6585 = 1
# length of line 6586 = 5
# length of line 6587 = 19
# length of line 6588 = 1
# length of line 6589 = 6
# length of line 6590 = 45
# length of line 6591 = 44
# length of line 6592 = 1
# length of line 6593 = 5
# length of line 6594 = 20
# length of line 6595 = 1
# length of line 6596 = 6
# length of line 6597 = 30
# length of line 6598 = 1
# length of line 6599 = 7
# length of line 6600 = 51
# length of line 6601 = 38
# length of line 6602 = 1
# length of line 6603 = 8
# length of line 6604 = 1
# length of line 6605 = 5
# length of line 6606 = 40
# length of line 6607 = 24
# length of line 6608 = 1
# length of line 6609 = 17
# length of line 6610 = 1
# length of line 6611 = 6
# length of line 6612 = 44
# length of line 6613 = 43
# length of line 6614 = 43
# length of line 6615 = 43
# length of line 6616 = 41
# length of line 6617 = 42
# length of line 6618 = 44
# length of line 6619 = 47
# length of line 6620 = 1
# length of line 6621 = 5
# length of line 6622 = 27
# length of line 6623 = 26
# length of line 6624 = 1
# length of line 6625 = 18
# length of line 6626 = 1
# length of line 6627 = 17
# length of line 6628 = 18
# length of line 6629 = 1
# length of line 6630 = 6
# length of line 6631 = 42
# length of line 6632 = 1
# length of line 6633 = 5
# length of line 6634 = 47
# length of line 6635 = 43
# length of line 6636 = 18
# length of line 6637 = 1
# length of line 6638 = 13
# length of line 6639 = 1
# length of line 6640 = 6
# length of line 6641 = 21
# length of line 6642 = 38
# length of line 6643 = 44
# length of line 6644 = 47
# length of line 6645 = 17
# length of line 6646 = 1
# length of line 6647 = 8
# length of line 6648 = 1
# length of line 6649 = 5
# length of line 6650 = 46
# length of line 6651 = 46
# length of line 6652 = 47
# length of line 6653 = 44
# length of line 6654 = 47
# length of line 6655 = 49
# length of line 6656 = 36
# length of line 6657 = 43
# length of line 6658 = 20
# length of line 6659 = 1
# length of line 6660 = 5
# length of line 6661 = 18
# length of line 6662 = 42
# length of line 6663 = 29
# length of line 6664 = 1
# length of line 6665 = 5
# length of line 6666 = 18
# length of line 6667 = 51
# length of line 6668 = 37
# length of line 6669 = 52
# length of line 6670 = 41
# length of line 6671 = 34
# length of line 6672 = 49
# length of line 6673 = 20
# length of line 6674 = 1
# length of line 6675 = 35
# length of line 6676 = 1
# length of line 6677 = 28
# length of line 6678 = 1
# length of line 6679 = 5
# length of line 6680 = 50
# length of line 6681 = 36
# length of line 6682 = 21
# length of line 6683 = 1
# length of line 6684 = 5
# length of line 6685 = 19
# length of line 6686 = 46
# length of line 6687 = 45
# length of line 6688 = 38
# length of line 6689 = 38
# length of line 6690 = 49
# length of line 6691 = 44
# length of line 6692 = 1
# length of line 6693 = 8
# length of line 6694 = 1
# length of line 6695 = 5
# length of line 6696 = 53
# length of line 6697 = 45
# length of line 6698 = 31
# length of line 6699 = 1
# length of line 6700 = 16
# length of line 6701 = 1
# length of line 6702 = 57
# length of line 6703 = 1
# length of line 6704 = 6
# length of line 6705 = 21
# length of line 6706 = 1
# length of line 6707 = 5
# length of line 6708 = 25
# length of line 6709 = 46
# length of line 6710 = 1
# length of line 6711 = 6
# length of line 6712 = 44
# length of line 6713 = 44
# length of line 6714 = 36
# length of line 6715 = 25
# length of line 6716 = 1
# length of line 6717 = 14
# length of line 6718 = 21
# length of line 6719 = 44
# length of line 6720 = 52
# length of line 6721 = 41
# length of line 6722 = 44
# length of line 6723 = 33
# length of line 6724 = 1
# length of line 6725 = 5
# length of line 6726 = 20
# length of line 6727 = 41
# length of line 6728 = 43
# length of line 6729 = 46
# length of line 6730 = 48
# length of line 6731 = 47
# length of line 6732 = 39
# length of line 6733 = 44
# length of line 6734 = 47
# length of line 6735 = 38
# length of line 6736 = 44
# length of line 6737 = 46
# length of line 6738 = 38
# length of line 6739 = 47
# length of line 6740 = 15
# length of line 6741 = 1
# length of line 6742 = 6
# length of line 6743 = 25
# length of line 6744 = 38
# length of line 6745 = 42
# length of line 6746 = 46
# length of line 6747 = 47
# length of line 6748 = 1
# length of line 6749 = 5
# length of line 6750 = 42
# length of line 6751 = 50
# length of line 6752 = 42
# length of line 6753 = 53
# length of line 6754 = 28
# length of line 6755 = 1
# length of line 6756 = 6
# length of line 6757 = 18
# length of line 6758 = 41
# length of line 6759 = 39
# length of line 6760 = 51
# length of line 6761 = 41
# length of line 6762 = 24
# length of line 6763 = 42
# length of line 6764 = 46
# length of line 6765 = 28
# length of line 6766 = 1
# length of line 6767 = 16
# length of line 6768 = 1
# length of line 6769 = 64
# length of line 6770 = 23

# %% [markdown]
# Get every third word between the second and the 15th words from poem.txt.

# %% [markdown]
# Print the last word from the file and change the second last characted in the string to 'g'.

# %% [markdown]
# State if the above operation completed successfully. State reasons

# %% [markdown]
# # Find types of Python variables and functions

# %% [markdown]
# Find what are the types of the following and state if they are mutable of immutable

# %%
values = [None, 1, 1.0, add, (1, 'a', 3, 'b'), [1, 'a', 3, 'b']]
for value in values:
    mutable = isinstance(value, (list, dict, set, bytearray))
    print(type(value).__name__, 'Mutable' if mutable else 'Immutable')
# Out:
# NoneType Immutable
# int Immutable
# float Immutable
# function Immutable
# tuple Immutable
# list Mutable

# %% [markdown]
# Append new elements at the end of a list

# %% [markdown]
# Loop through each element of the list

# %% [markdown]
# Use a indexing operator

# %%
str_indexing = "Python"
lastchar = str_indexing[-1]
print(lastchar)
# Out:
# n

# %% [markdown]
# Concatenate two lists

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
print(list1 + list2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Use * to repeat lists

# %%
print(list1 * 3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# Use the in operator to check if something is in a list

# %% [markdown]
# Initialize a string and slice the first 1, 2 and 3 characters. Then from 3rd to end.

# %% [markdown]
# Take a first name and a last name and then concatenate the last name with 3 times the first name and show result.

# %% [markdown]
# Take a string with four words. Use the split function to display the second and the last words

# %% [markdown]
# Concatenate a number with a string. Update following:

# %% [markdown]
# ## Dictionaries associated with lists

# %% [markdown]
# Create a list of keys and values

# %% [markdown]
# ### Creating Dictionaries
#
# Create a list of keys and values

# %%
x = {'name': 'Maharshi', 'age': 20, 'city': 'Indore'}
print("dict:", x)
# Out:
# dict: {'name': 'Maharshi', 'age': 20, 'city': 'Indore'}

# %%
x['Prithwish'] = None
print(x)
# Out:
# {'name': 'Maharshi', 'age': 20, 'city': 'Indore', 'Prithwish': None}

# %% [markdown]
# Iterate over all the keys

# %%
for key in x:
    print(key)
# Out:
# name
# age
# city
# Prithwish

# %% [markdown]
# Iterate over all the values

# %% [markdown]
# Iterate over all the key-value pairs in the list

# %% [markdown]
# Unpack the following sequence into different variables

# %%
('Prithwish','IIITG','prithwish.sen@iiitg','CSE')
# Out:
# ('Prithwish', 'IIITG', 'prithwish.sen@iiitg', 'CSE')

# %% [markdown]
# Use Python's in-built methods for string formatting

# %%
sales_record = {
    'price': 3.24,
    'num_items': 4,
    'person': 'Prithwish'
}

sales_statement = '{} got {} item(s) at a cost of {} each for a total of {}'
print(sales_statement.format(
    sales_record['person'],
    sales_record['num_items'],
    sales_record['price'],
    sales_record['price'] * sales_record['num_items']
))
# Out:
# Prithwish got 4 item(s) at a cost of 3.24 each for a total of 12.96

# %% [markdown]
# Take a list of 10 elements and convert into json using  json library. Demonstrate use of loads and dumps

# %% [markdown]
# # Python objects and functions

# %% [markdown]
# Take the following code:

# %%
class students:
    dept = "Department of CSE"
    def assign_name(self, n):
        self.name = n
    def assign_location(self, l):
        self.location = l

# %% [markdown]
# Create a object of the class above. Set name and location of your choice.

# %% [markdown]
# Format accordingly and print in a manner so we see something like : "Dip Sankar lives in Guwahati, Assam, India and works in the Department of CSE". The name and location should be of your choice. Use 1 print only

# %%
from collections import namedtuple

Student = namedtuple('Student', ['name', 'location', 'dept'])
student = Student('Maharshi', 'Pune', 'CSE')

sentence = '{} lives in {} and is a student in the {}'
print(sentence.format(student.name, student.location, student.dept))
# Out:
# Maharshi lives in Pune and is a student in the CSE

# %% [markdown]
# Create two lists of 5 elements each. Map the min function to the lists using map(). Print the minimum object.

# %% [markdown]
# Iterate through that object and print the elements.

# %% [markdown]
# # Working with CSV

# %% [markdown]
# Let's import a file with fuel economy data

# %%
import csv

with open('mpg.csv', newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    mpg = list(reader)

print(mpg[:2])
# Out:
# [{'': '1', 'manufacturer': 'audi', 'model': 'a4', 'displ': '1.8', 'year': '1999', 'cyl': '4', 'trans': 'auto(l5)', 'drv': 'f', 'cty': '18', 'hwy': '29', 'fl': 'p', 'class': 'compact'}, {'': '2', 'manufacturer': 'audi', 'model': 'a4', 'displ': '1.8', 'year': '1999', 'cyl': '4', 'trans': 'manual(m5)', 'drv': 'f', 'cty': '21', 'hwy': '29', 'fl': 'p', 'class': 'compact'}]

# %% [markdown]
# Find out how many items are there in the dictionary

# %%
print("Number of items in the first dictionary:", len(mpg[0]))
# Out:
# Number of items in the first dictionary: 12

# %% [markdown]
# Find the column names with keys

# %%
print(mpg[0].keys())
# Out:
# dict_keys(['', 'manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty', 'hwy', 'fl', 'class'])

# %% [markdown]
# Find the average cty fuel economy across all cars. All values in the dictionaries are strings.

# %% [markdown]
# Find the average hwy fuel economy across all cars

# %% [markdown]
# Use set to return the unique values for the number of cylinders the cars.

# %%
cylinders = set(d['cyl'] for d in mpg)
print(cylinders)
# Out:
# {'5', '8', '6', '4'}

# %% [markdown]
# Group the cars by number of cylinder, and finding the average cty mpg for each group.

# %%
MpgByCyl = []

for c in cylinders:
    summpg = 0
    typecount = 0
    for d in mpg:
        if d['cyl'] == c:
            summpg += int(d['cty'])
            typecount += 1
    MpgByCyl.append((c, summpg / typecount))

MpgByCyl.sort(key=lambda x: x[0])
MpgByCyl
# Out:
# [('4', 21.012345679012345),
#  ('5', 20.5),
#  ('6', 16.21518987341772),
#  ('8', 12.571428571428571)]

# %% [markdown]
# Return the unique values for the class types in our dataset using set.

# %%
vehicleclass = set(d['class'] for d in mpg)
print(vehicleclass)
# Out:
# {'midsize', 'suv', '2seater', 'pickup', 'minivan', 'subcompact', 'compact'}

# %% [markdown]
# Find average miles per gallon in the highway for each class of vehicles

# %%
MileageByClass = []

for t in vehicleclass:
    sumpg = 0
    classCount = 0
    for d in mpg:
        if d['class'] == t:
            sumpg += int(d['hwy'])
            classCount += 1
    MileageByClass.append((t, sumpg / classCount))

MileageByClass.sort(key=lambda x: x[1])
MileageByClass
# Out:
# [('pickup', 16.87878787878788),
#  ('suv', 18.129032258064516),
#  ('minivan', 22.363636363636363),
#  ('2seater', 24.8),
#  ('midsize', 27.29268292682927),
#  ('subcompact', 28.142857142857142),
#  ('compact', 28.29787234042553)]
